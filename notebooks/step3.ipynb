# %%
import numpy as np

from level1.functions import f_returns_on_df, f_mu_on_df, f_sigma_on_df
from portfolio_utils import load_datas, f_yield, f_volatility
from level3.functions import PortfolioRobustness
from level2.functions import optimize

# Charger les données
df = load_datas()

# %%
df.info()

# %%
set(df.index.year)

# %%
c = 0.001
K = 2
delta_tol = 0.01
num_assets = df.shape[1]
w0 = np.array(num_assets * [0])
w0[2] = 1
w0.shape

# %%
portfilio_robustness = PortfolioRobustness(df, c=c, w0=w0, K=K, delta_tol=delta_tol)

# %%
portfilio_robustness.optimize(300, 1000)

# %%
score = portfilio_robustness.compute_score(vol_per=0.4, cost_per=0.2, yield_per=0.2, yield_std_per=0.1, vol_std_per=0.1)

# %%
best_idx = np.argmin(score)
w_robust = portfilio_robustness.frontier_weights[best_idx]
print(f"Portefeuille robuste sélectionné :")
print(f"Rendement : {portfilio_robustness.frontier_yields[best_idx]:.4f}")
print(f"Volatilité : {portfilio_robustness.frontier_volatility[best_idx]:.4f}")
print(f"Coût : {portfilio_robustness.frontier_cost[best_idx]:.4f}")
print(f"Instabilité rendement (std) : {portfilio_robustness.std_yields[best_idx]:.4f}")
for i, weight in enumerate(w_robust):
    if weight > 1e-4:
        print(f"  {df.columns[i]} : {weight:.4f}")
